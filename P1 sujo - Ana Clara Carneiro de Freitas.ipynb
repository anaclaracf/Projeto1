# %% [markdown]
# # Projeto 1 - Ciência dos Dados
# ### Aluno: Ana Clara Carneiro de Freitas - 2A
#
# <img src="OCDE.jpg" width=600 height=500 align="center">

# %% [markdown]
# ## Pergunta a ser respondida:
# Os três principais objetivos da OCDE (Organização para a Cooperação e Desenvolvimento Económico) é que seus membros, ao ingressarem na organização, tenham a possibilidade de desenvolver a economia, o emprego e o nível de vida em seus países.  Dessa forma, foi elaborado a seguinte hipótese: Ao se tornar membro desta organização, é possível perceber que esses setores (economia, emprego e idh) são beneficiados?
#
# ## Explicação da hipótese e mecanismo:
# Logo, após elaborar a hipótese, foi iniciado a busca por dados, pesquisas sobre a Organização e seus países membros. Assim, primeiramente foram selecionados quais seriam os países escolhidos para validar a hipótese, sendo eles Israel, Chile e Estônia; pois tais países entraram no ano de 2010, possuindo um maior período de análise, mais dados e maior influência da OCDE na economia.
#
# Dessa maneira, quatro bases de dados foram analisadas e utilizadas para compor a pesquisa, entre elas estão a taxa de desemprego anual e o GDP por trabalhador de cada país para analisar se a taxa de empregados aumentou ao decorrer dos anos. Para o setor econômico foi analisado o GDP dos países membros e, para medir se o nível de vida melhorou, foi utilizado o IDH. Afinal, com a ajuda desses dados foi possível analisar analíticamente todos os anos, principalmente antes, durante e depois da entrada; e ver como foi o comportamento desses dados durante esse período. A utilização destes permitiu uma visão mais ampla, tanto da parte econômica quanto da social dos países escolhidos.
#
# Após isso, foi necessário escolher qual país seria utilizado para comparar os dados. Assim, um dos critérios analisados para escolher tal país foi um IDH parecido e, depois de ler mais sobre a Organização, foi possível descobrir que ela só aceita países compostos por economias com um elevado PIB per capita e Índice de Desenvolvimento Humano e que são considerados países desenvolvidos. Logo, com tal conceito em mente, a Colômbia foi escolhida como país à ser comparado, pois ela é um dos países que assinaram o acordo de adesão mas ainda não são membros, ou seja, possui um desenvolvimento semelhante aos outros escolhidos.
#
# Dessa forma, foi possível reunir informações o suficiente as quais poderiam ser capazes de comprovar ou refutar a hipótese.
#
#
# ### Recursos de busca:
# - https://www.cafetorah.com/taxa-de-desemprego-em-israel-e-a-menor-em-50-anos/
# - https://economia.estadao.com.br/noticias/geral,o-emprego-reflete-a-economia,10000014535
# - https://pt.wikipedia.org/wiki/Organiza%C3%A7%C3%A3o_para_a_Coopera%C3%A7%C3%A3o_e_Desenvolvimento_Econ%C3%B3mico
#
#
# ### fatores analisados:
# - desenvolver o emprego: *taxa de desemprego* e GDP por trabalhador
# - aumentar o nível de vida: idh e expectativa de vida
# - apoiar um crescimento económico duradouro: *gdp total* (objetivo de quantificar a atividade econômica de uma região)

# %% [markdown]
# # Análise dos dados:

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ana clara\Downloads

# %% [markdown]
# ### Base utilizada:

# %% [markdown]
# Desemprego:
# https://www.gapminder.org/tools/#$state$marker$axis_y$which=aged_15plus_unemployment_rate_percent&scaleType=linear&spaceRef:null;;;&chart-type=linechart
#
# PIB/trabalhador:
# https://www.gapminder.org/tools/#$state$time$value=2018;&entities$show$country$/$in@=isr&=chl&=est;;;;&marker$axis_y$which=gdpperemployee_us_inflation_adjusted&spaceRef:null;;;&chart-type=linechart
#
# IDH: https://www.gapminder.org/tools/#$state$time$value=2015;&marker$axis_y$which=hdi_human_development_index&scaleType=linear&spaceRef:null;;;&chart-type=linechart
#
# PIB/capita: https://www.gapminder.org/tools/#$state$marker$axis_y$which=gdp_per_capita_yearly_growth&scaleType=linear&spaceRef:null;;;&chart-type=linechart

# %%
desemprego = pd.read_excel('aged_15plus_unemployment_rate_percent.xlsx')
gdp_trabalhador = pd.read_excel('gdpperemployee_us_inflation_adjusted.xlsx')
idh = pd.read_excel('hdi_human_development_index.xlsx')
gdp_total = pd.read_excel('gdp_per_capita_yearly_growth.xlsx')
exp_vida = pd.read_excel('life_expectancy_years.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-63-1d621275a571> in <module>
# ----> 1 desemprego = pd.read_excel('aged_15plus_unemployment_rate_percent.xlsx')
#       2 gdp_trabalhador = pd.read_excel('gdpperemployee_us_inflation_adjusted.xlsx')
#       3 idh = pd.read_excel('hdi_human_development_index.xlsx')
#       4 gdp_total = pd.read_excel('gdp_per_capita_yearly_growth.xlsx')
#       5 exp_vida = pd.read_excel('life_expectancy_years.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     305
#     306     if not isinstance(io, ExcelFile):
# --> 307         io = ExcelFile(io, engine=engine)
#     308
#     309     return io.parse(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     392             self.book = xlrd.open_workbook(file_contents=data)
#     393         elif isinstance(self._io, compat.string_types):
# --> 394             self.book = xlrd.open_workbook(self._io)
#     395         else:
#     396             raise ValueError('Must explicitly set engine if not passing in'
#
# ~\Anaconda3\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'aged_15plus_unemployment_rate_percent.xlsx'

# %% [markdown]
# ### Informações sobre o desemprego:
#
# #### Todas as informações:

# %%
dados_novosD = desemprego.set_index("país")    
dados_novosD.head()
# Out:
#                    1947  1948  1949  1950  1951  1952  1953  1954  1955  1956  \
# país
# Afeganistão         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albânia             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Argélia             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Antígua e Barbuda   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                    ...    2008  2009   2010   2011   2012   2013  2014  2015  \
# país               ...
# Afeganistão        ...    2.49   NaN    NaN    NaN   1.69    NaN   NaN   NaN
# Albânia            ...   13.10  13.7  14.10  13.50  13.40  15.90  17.5  17.1
# Argélia            ...   11.30  10.2   9.96   9.96  11.00   9.82  10.2  11.2
# Angola             ...     NaN   NaN   9.43  16.80    NaN    NaN   NaN   NaN
# Antígua e Barbuda  ...     NaN   NaN    NaN    NaN    NaN    NaN   NaN   NaN
#
#                    2016  2017
# país
# Afeganistão         NaN   NaN
# Albânia            15.2  13.8
# Argélia            10.2  13.6
# Angola              NaN   NaN
# Antígua e Barbuda   NaN   NaN
#
# [5 rows x 71 columns]

# %%
paises_na_OCDE = []
paises_OCDE = ["Áustria", "Bélgica", 'Dinamarca', 'França', 'Grécia', 'Islândia', 'Irlanda', 'Itália', 'Luxemburgo', 'Noruega', 'Países Baixos', 'Portugal', 'Reino Unido', 'Suécia', 'Suíça', 'Turquia', 'Alemanha', 'Espanha', 'Canadá', 'Estados Unidos', 'Japão', 'Finlândia', 'Austrália', 'Nova Zelândia', 'México', 'República Checa', 'Hungria', 'Polónia', 'Coreia do Sul', 'Eslováquia', 'Chile', 'Eslovênia', 'Israel', 'Estónia', 'Letônia', 'Lituânia']
for pais in desemprego ["país"]:
    if pais in paises_OCDE:
        paises_na_OCDE.append("sim")
    else:
        paises_na_OCDE.append('não')
dados_novosD["Está na OCDE"]=paises_na_OCDE
dados_novosD
# Out:
#                          1947   1948   1949   1950   1951   1952   1953  \
# país
# Afeganistão               NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albânia                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Argélia                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Angola                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Antígua e Barbuda         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Argentina                 NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Armênia                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Austrália                 NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Áustria                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Azerbaijão                NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bahamas                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Barém                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bangladesh                NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Barbados                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Belarus                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bélgica                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Belize                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Benin                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Butão                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bolívia                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bósnia e Herzegovina      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Botsuana                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Brasil                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Brunei                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bulgária                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Burkina Faso              NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Burundi                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Camboja                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Camarões                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Canadá                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...                       ...    ...    ...    ...    ...    ...    ...
# Sudão                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Suriname                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Suazilândia               NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Suécia                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Suíça                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Síria                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Tajiquistão               NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Tanzânia                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Tailândia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Timor-Leste               NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Ir                        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Tonga                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Trinidad e Tobago         NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Tunísia                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Peru                      NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Turcomenistão             NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Tuvalu                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Uganda                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Ucrânia                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Emirados Árabes Unidos    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Reino Unido               NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Estados Unidos          390.0  380.0  590.0  530.0  330.0  300.0  290.0
# Uruguai                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Uzbequistão               NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Vanuatu                   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Venezuela                 NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Vietnã                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Iémen                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zâmbia                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zimbábue                  NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                          1954   1955   1956      ...         2009     2010  \
# país                                             ...
# Afeganistão               NaN    NaN    NaN      ...          NaN      NaN
# Albânia                   NaN    NaN    NaN      ...        13.70   14.100
# Argélia                   NaN    NaN    NaN      ...        10.20    9.960
# Angola                    NaN    NaN    NaN      ...          NaN    9.430
# Antígua e Barbuda         NaN    NaN    NaN      ...          NaN      NaN
# Argentina                 NaN    NaN    NaN      ...         8.65    7.710
# Armênia                   NaN    NaN    NaN      ...          NaN      NaN
# Austrália                 NaN    NaN    NaN      ...         5.56    5.210
# Áustria                   NaN    NaN    NaN      ...         5.30    4.820
# Azerbaijão                NaN    NaN    NaN      ...         5.74    5.630
# Bahamas                   NaN    NaN    NaN      ...        14.30      NaN
# Barém                     NaN    NaN    NaN      ...          NaN    1.130
# Bangladesh                NaN    NaN    NaN      ...         5.00    3.380
# Barbados                  NaN    NaN    NaN      ...        10.00   10.700
# Belarus                   NaN    NaN    NaN      ...          NaN      NaN
# Bélgica                   NaN    NaN    NaN      ...         7.91    8.290
# Belize                    NaN    NaN    NaN      ...          NaN      NaN
# Benin                     NaN    NaN    NaN      ...          NaN    1.040
# Butão                     NaN    NaN    NaN      ...         3.96    3.320
# Bolívia                   NaN    NaN    NaN      ...          NaN      NaN
# Bósnia e Herzegovina      NaN    NaN    NaN      ...        24.10   27.300
# Botsuana                  NaN    NaN    NaN      ...          NaN      NaN
# Brasil                    NaN    NaN    NaN      ...          NaN      NaN
# Brunei                    NaN    NaN    NaN      ...          NaN      NaN
# Bulgária                  NaN    NaN    NaN      ...         6.82   10.300
# Burkina Faso              NaN    NaN    NaN      ...          NaN      NaN
# Burundi                   NaN    NaN    NaN      ...          NaN      NaN
# Camboja                   NaN    NaN    NaN      ...          NaN      NaN
# Camarões                  NaN    NaN    NaN      ...          NaN    4.110
# Canadá                    NaN    NaN    NaN      ...         8.34    8.060
# ...                       ...    ...    ...      ...          ...      ...
# Sudão                     NaN    NaN    NaN      ...        13.00      NaN
# Suriname                  NaN    NaN    NaN      ...         8.72    7.150
# Suazilândia               NaN    NaN    NaN      ...          NaN      NaN
# Suécia                    NaN    NaN    NaN      ...         8.35    8.610
# Suíça                     NaN    NaN    NaN      ...         4.12    4.810
# Síria                     NaN    NaN    NaN      ...         8.14    8.610
# Tajiquistão               NaN    NaN    NaN      ...        11.50      NaN
# Tanzânia                  NaN    NaN    NaN      ...         2.50      NaN
# Tailândia                 NaN    NaN    NaN      ...         1.49    0.622
# Timor-Leste               NaN    NaN    NaN      ...          NaN    3.300
# Ir                        NaN    NaN    NaN      ...          NaN      NaN
# Tonga                     NaN    NaN    NaN      ...          NaN      NaN
# Trinidad e Tobago         NaN    NaN    NaN      ...         5.28    3.770
# Tunísia                   NaN    NaN    NaN      ...       133.00  130.000
# Peru                      NaN    NaN    NaN      ...       126.00  107.000
# Turcomenistão             NaN    NaN    NaN      ...          NaN  400.000
# Tuvalu                    NaN    NaN    NaN      ...          NaN      NaN
# Uganda                    NaN    NaN    NaN      ...          NaN      NaN
# Ucrânia                   NaN    NaN    NaN      ...       884.00  810.000
# Emirados Árabes Unidos    NaN    NaN    NaN      ...          NaN      NaN
# Reino Unido               NaN    NaN    NaN      ...       754.00  779.000
# Estados Unidos          550.0  440.0  410.0      ...       925.00  963.000
# Uruguai                   NaN    NaN    NaN      ...       774.00  716.000
# Uzbequistão               NaN    NaN    NaN      ...       504.00  536.000
# Vanuatu                   NaN    NaN    NaN      ...       546.00      NaN
# Venezuela                 NaN    NaN    NaN      ...       610.00  711.000
# Vietnã                    NaN    NaN    NaN      ...       174.00  111.000
# Iémen                     NaN    NaN    NaN      ...          NaN      NaN
# Zâmbia                    NaN    NaN    NaN      ...          NaN      NaN
# Zimbábue                  NaN    NaN    NaN      ...          NaN      NaN
#
#                           2011    2012     2013     2014     2015     2016  \
# país
# Afeganistão                NaN    1.69      NaN      NaN      NaN      NaN
# Albânia                  13.50   13.40   15.900   17.500   17.100   15.200
# Argélia                   9.96   11.00    9.820   10.200   11.200   10.200
# Angola                   16.80     NaN      NaN      NaN      NaN      NaN
# Antígua e Barbuda          NaN     NaN      NaN      NaN      NaN      NaN
# Argentina                 7.18    7.22    7.100    7.270      NaN      NaN
# Armênia                    NaN     NaN      NaN   17.500   18.300   17.600
# Austrália                 5.08    5.22    5.660    6.080    6.060    5.710
# Áustria                   4.56    4.87    5.330    5.620    5.720    6.010
# Azerbaijão                5.42    5.19    4.970    4.910    4.960    5.000
# Bahamas                  14.50   14.00   16.200   13.800   12.000   12.700
# Barém                      NaN     NaN      NaN      NaN      NaN      NaN
# Bangladesh                 NaN     NaN    4.430      NaN      NaN    4.350
# Barbados                 11.20   11.60   11.600   12.200   11.300    9.720
# Belarus                    NaN     NaN      NaN      NaN      NaN    5.840
# Bélgica                   7.14    7.54    8.430    8.520    8.480    7.830
# Belize                     NaN   14.30   11.700   11.600    9.970    7.910
# Benin                     2.65     NaN      NaN      NaN      NaN      NaN
# Butão                     3.23    2.05    2.870    2.630    2.450      NaN
# Bolívia                    NaN     NaN      NaN      NaN      NaN      NaN
# Bósnia e Herzegovina     27.60   28.00   27.400   27.500   27.600   25.400
# Botsuana                   NaN     NaN      NaN      NaN      NaN      NaN
# Brasil                     NaN    7.19    6.990    6.670    8.440   11.600
# Brunei                     NaN     NaN      NaN    6.970      NaN      NaN
# Bulgária                 11.30   12.30   12.900   11.400    9.140    7.570
# Burkina Faso               NaN     NaN      NaN    6.480      NaN      NaN
# Burundi                    NaN     NaN      NaN    1.570      NaN      NaN
# Camboja                    NaN    1.28      NaN      NaN      NaN      NaN
# Camarões                   NaN     NaN      NaN      NaN      NaN      NaN
# Canadá                    7.51    7.29    7.070    6.910    6.910    7.000
# ...                        ...     ...      ...      ...      ...      ...
# Sudão                      NaN     NaN      NaN      NaN      NaN      NaN
# Suriname                  7.54    8.10    6.600    6.940    7.220      NaN
# Suazilândia                NaN     NaN      NaN      NaN      NaN   22.700
# Suécia                    7.80    7.98    8.050    7.950    7.430    6.990
# Suíça                     4.41    4.48    4.750    4.830    4.800    4.920
# Síria                      NaN     NaN      NaN      NaN      NaN      NaN
# Tajiquistão                NaN     NaN      NaN      NaN      NaN      NaN
# Tanzânia                   NaN     NaN      NaN    2.120      NaN      NaN
# Tailândia                 0.66    0.58    0.489    0.576    0.597    0.688
# Timor-Leste                NaN     NaN   11.000      NaN      NaN      NaN
# Ir                        1.98     NaN      NaN      NaN    2.200      NaN
# Tonga                      NaN     NaN      NaN      NaN      NaN      NaN
# Trinidad e Tobago         3.25    3.45    2.460    2.220    2.210    2.970
# Tunísia                 183.00  176.00  159.000      NaN  152.000  155.000
# Peru                    880.00  815.00  873.000  988.000  102.000  108.000
# Turcomenistão              NaN     NaN      NaN      NaN      NaN      NaN
# Tuvalu                     NaN     NaN      NaN      NaN      NaN      NaN
# Uganda                     NaN     NaN      NaN      NaN      NaN      NaN
# Ucrânia                 786.00  753.00  717.000  927.000  914.000  935.000
# Emirados Árabes Unidos     NaN     NaN      NaN      NaN      NaN  164.000
# Reino Unido             804.00  789.00  753.000  611.000  530.000  481.000
# Estados Unidos          895.00  807.00  737.000  617.000  528.000  487.000
# Uruguai                 631.00  645.00  644.000  655.000  749.000  784.000
# Uzbequistão             496.00  487.00  486.000  509.000  515.000  516.000
# Vanuatu                    NaN     NaN      NaN      NaN      NaN      NaN
# Venezuela               690.00  660.00      NaN      NaN      NaN      NaN
# Vietnã                  999.00  103.00  125.000  126.000  186.000  185.000
# Iémen                      NaN     NaN      NaN  135.000      NaN      NaN
# Zâmbia                     NaN  785.00      NaN      NaN      NaN      NaN
# Zimbábue                537.00     NaN      NaN  113.000      NaN      NaN
#
#                           2017  Está na OCDE
# país
# Afeganistão                NaN           não
# Albânia                  13.80           não
# Argélia                  13.60           não
# Angola                     NaN           não
# Antígua e Barbuda          NaN           não
# Argentina                 8.35           não
# Armênia                  17.80           não
# Austrália                 5.59           sim
# Áustria                   5.50           sim
# Azerbaijão                5.00           não
# Bahamas                    NaN           não
# Barém                      NaN           não
# Bangladesh                4.37           não
# Barbados                   NaN           não
# Belarus                   5.65           não
# Bélgica                   7.09           sim
# Belize                    9.00           não
# Benin                      NaN           não
# Butão                      NaN           não
# Bolívia                    NaN           não
# Bósnia e Herzegovina     20.50           não
# Botsuana                   NaN           não
# Brasil                   12.80           não
# Brunei                    9.32           não
# Bulgária                  6.16           não
# Burkina Faso               NaN           não
# Burundi                    NaN           não
# Camboja                    NaN           não
# Camarões                   NaN           não
# Canadá                    6.34           sim
# ...                        ...           ...
# Sudão                      NaN           não
# Suriname                   NaN           não
# Suazilândia                NaN           não
# Suécia                    6.72           sim
# Suíça                     4.80           sim
# Síria                      NaN           não
# Tajiquistão                NaN           não
# Tanzânia                   NaN           não
# Tailândia                  NaN           não
# Timor-Leste                NaN           não
# Ir                         NaN           não
# Tonga                      NaN           não
# Trinidad e Tobago          NaN           não
# Tunísia                 154.00           não
# Peru                    108.00           não
# Turcomenistão              NaN           não
# Tuvalu                     NaN           não
# Uganda                     NaN           não
# Ucrânia                 951.00           não
# Emirados Árabes Unidos  246.00           não
# Reino Unido             433.00           sim
# Estados Unidos          436.00           sim
# Uruguai                 789.00           não
# Uzbequistão                NaN           não
# Vanuatu                    NaN           não
# Venezuela                  NaN           não
# Vietnã                  189.00           não
# Iémen                      NaN           não
# Zâmbia                     NaN           não
# Zimbábue                   NaN           não
#
# [186 rows x 72 columns]

# %% [markdown]
# #### Limpeza da base dos dados:

# %%
dados_novo = dados_novosD.iloc[:,51:71]
dados_limposD=dados_novo[~dados_novosD[1998].isin(["NaN"])]
dados_limposD.head()
# Out:
#             1998   1999   2000   2001   2002   2003   2004   2005   2006  \
# país
# Argentina  12.70  14.10  15.00  17.30  19.60  15.40  13.50  11.50  10.10
# Austrália   7.68   6.87   6.28   6.74   6.37   5.93   5.39   5.03   4.78
# Áustria     5.52   4.70   4.69   4.01   4.85   4.78   5.83   5.63   5.24
# Bahamas     7.65   7.45    NaN   6.87   9.05  10.80  10.20  10.20   7.54
# Barbados   12.40  10.60   9.35   9.85  10.30  11.00   9.57   9.08   8.73
#
#            2007  2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# país
# Argentina  8.47  7.84   8.65   7.71   7.18   7.22   7.10   7.27    NaN    NaN
# Austrália  4.38  4.23   5.56   5.21   5.08   5.22   5.66   6.08   6.06   5.71
# Áustria    4.86  4.13   5.30   4.82   4.56   4.87   5.33   5.62   5.72   6.01
# Bahamas    7.88  8.18  14.30    NaN  14.50  14.00  16.20  13.80  12.00  12.70
# Barbados   7.41  8.12  10.00  10.70  11.20  11.60  11.60  12.20  11.30   9.72
#
#            2017
# país
# Argentina  8.35
# Austrália  5.59
# Áustria    5.50
# Bahamas     NaN
# Barbados    NaN

# %% [markdown]
# #### Dados selecionados dos paises membros da OCDE que entraram no ano de 2010 e país que não participa da organização:
# ##### (obs: participantes: Israel, Chile, Estônia; não participantes: Colômbia)

# %%
dados_paisesD = dados_limposD.loc[["Israel","Chile","Estônia","Colômbia","Argentina"]]
dados_paisesD
# Out:
#             1998  1999  2000  2001  2002   2003  2004   2005   2006   2007  \
# país
# Israel     10.70  11.2  11.1  11.8  12.9  13.50  13.0  11.30  10.70   9.38
# Chile       7.31  11.2  10.5  10.4  10.2   9.77  10.2   9.34   9.02   8.43
# Estônia     9.51  11.6  13.4  13.1  10.0  11.30  10.2   8.03   5.91   4.59
# Colômbia   15.00  20.1  20.5  15.0  15.6  14.20  13.7  11.90    NaN  11.20
# Argentina  12.70  14.1  15.0  17.3  19.6  15.40  13.5  11.50  10.10   8.47
#
#             2008   2009   2010   2011   2012  2013  2014  2015  2016  2017
# país
# Israel      7.70   9.53   8.48   7.14   6.86  6.21  5.89  5.25  4.80  4.21
# Chile       9.29  11.30   8.42   7.34   6.66  6.21  6.66  6.51  6.74  6.96
# Estônia     5.45  13.50  16.70  12.30  10.00  8.63  7.35  6.19  6.76  5.76
# Colômbia   11.30  12.10  11.00  10.10   9.74  9.05  8.57  8.30  8.69  8.87
# Argentina   7.84   8.65   7.71   7.18   7.22  7.10  7.27   NaN   NaN  8.35

# %%
dados_testeD = dados_paisesD.transpose()
plt.plot(dados_paisesD.loc["Israel"])
plt.plot(dados_paisesD.loc["Chile"])
plt.plot(dados_paisesD.loc["Estônia"])
plt.xlabel('Anos')
plt.ylabel("Porcentagem de desempregados")
plt.title('Taxa de desempregados dos países da OCDE')
plt.legend()
plt.grid()

# %% [markdown]
# #### Gráfico comparativo com o país fora da OCDE:
# Para melhor entendimento, os países membros da OCDE estão em azul e o não-membro está de vermelho

# %%
pais_comparadoD = dados_paisesD.transpose()
plt.plot(dados_paisesD.loc["Israel"], color = "blue")
plt.plot(dados_paisesD.loc["Chile"], color = "darkblue")
plt.plot(dados_paisesD.loc["Estônia"], color = "aqua")
plt.plot(dados_paisesD.loc["Colômbia"], color = "red")
plt.plot(dados_paisesD.loc["Argentina"], color = "green")
plt.xlabel('Anos')
plt.ylabel("Porcentagem de desempregados")
plt.title('Taxa de desempregados comparativa')
plt.legend()
plt.grid()

# %% [markdown]
# ### Informações sobre GDP/trabalhador:
# #### Todas as informações e limpeza da base:

# %%
dados_novosGDP = gdp_trabalhador.set_index("country")
dados_novosGDP = dados_novosGDP.iloc[:,1:33]
dados_novosGDP.head()

# %% [markdown]
# #### Dados selecionados dos paises membros da OCDE que entraram no ano de 2010 e país que não participa da organização:
# ##### (obs: participantes: Israel, Chile, Estônia; não participantes: Colômbia)

# %%
dados_paisesGDP = dados_novosGDP.loc[["Israel","Chile","Estonia","Colombia",'Argentina']]
dados_paisesGDP

# %%
dados_testeGPD = dados_paisesGDP.transpose()
plt.plot(dados_paisesGDP.loc["Israel"])
plt.plot(dados_paisesGDP.loc["Chile"])
plt.plot(dados_paisesGDP.loc["Estonia"])
plt.xlabel('Anos')
plt.ylabel("PIB/trabalhador")
plt.title('PIB/trabalhador dos países da OCDE')
plt.legend()
plt.grid()

# %% [markdown]
# #### Gráfico comparativo com o país fora da OCDE:
# Para melhor entendimento, os países membros da OCDE estão em azul e o não-membro está de vermelho

# %%
dados_testeGPD = dados_paisesGDP.transpose()
plt.plot(dados_paisesGDP.loc["Israel"], color = "blue")
plt.plot(dados_paisesGDP.loc["Chile"], color = "darkblue")
plt.plot(dados_paisesGDP.loc["Estonia"], color = "aqua")
plt.plot(dados_paisesGDP.loc["Colombia"], color = "red")
plt.plot(dados_paisesGDP.loc["Argentina"], color = "green")
plt.xlabel('Anos')
plt.ylabel("PIB/trabalhador")
plt.title('PIB/trabalhador comparativo')
plt.legend()
plt.grid()

# %% [markdown]
# ## Informações sobre o IDH:

# %%
dados_novosIDH = idh.set_index("country")
dados_novosIDH.head()

# %%
dados_paisesIDH = dados_novosIDH.loc[["Israel","Chile","Estonia","Colombia","Argentina"]]
dados_paisesIDH

# %%
dados_testeIDH = dados_paisesIDH.transpose()
plt.plot(dados_paisesIDH.loc["Israel"])
plt.plot(dados_paisesIDH.loc["Chile"])
plt.plot(dados_paisesIDH.loc["Estonia"])
plt.plot(dados_paisesIDH.loc["Colombia"])
plt.plot(dados_paisesIDH.loc["Argentina"])
plt.xlabel('Anos')
plt.ylabel("IDH")
plt.title('IDH dos países da OCDE')
plt.legend()
plt.grid()

# %% [markdown]
# ## Informações sobre GDP total

# %%
dados_novosGDP_total = gdp_total.set_index("country")
dados_novosGDP_total = dados_novosGDP_total.iloc[:,209:213]
dados_novosGDP_total.head()

# %%
dados_paisesGDP_total = dados_novosGDP_total.loc[["Israel","Chile","Estonia","Colombia","Argentina"]]
dados_paisesGDP_total

# %%
dados_testeGDP_total = dados_paisesGDP_total.transpose()
plt.plot(dados_paisesGDP_total.loc["Israel"])
plt.plot(dados_paisesGDP_total.loc["Chile"])
plt.plot(dados_paisesGDP_total.loc["Estonia"])
plt.plot(dados_paisesGDP_total.loc["Colombia"])
plt.plot(dados_paisesGDP_total.loc["Argentina"])
plt.xlabel('Anos')
plt.ylabel("GDP total")
plt.title('GDP dos países da OCDE')
plt.legend()
plt.grid()

# %% [markdown]
# ## Informações sobre expectativa de vida:

# %%
dados_novosExp_vida = exp_vida.set_index("country")
dados_novosExp_vida = dados_novosExp_vida.iloc[:,190:219]
dados_novosExp_vida.head()

# %%
dados_paisesExp_vida = dados_novosExp_vida.loc[["Israel","Chile","Estonia","Colombia",'Argentina']]
dados_paisesExp_vida

# %%
dados_testeExp_vida = dados_paisesExp_vida.transpose()
plt.plot(dados_paisesExp_vida.loc["Israel"])
plt.plot(dados_paisesExp_vida.loc["Chile"])
plt.plot(dados_paisesExp_vida.loc["Estonia"])
plt.plot(dados_paisesExp_vida.loc["Colombia"])
plt.plot(dados_paisesExp_vida.loc["Argentina"])
plt.xlabel('Anos')
plt.ylabel("Expectativa de vida")
plt.title('expectativa de vida dos países da OCDE')
plt.legend()
plt.grid()

# %% [markdown]
# # Conclusão:
# Após realizar a leitura dos dados e feitura dos gráficos, foi possível tirar algumas conclusões sobre a hipótese elaborada anteriormente. Entre elas, está o fato de que, após os países ingressarem na Organização, num primeiro momento as taxas de desemprego sofreram um aumento, muitas vezes por causa da crise de 2008 ou apenas algumas mudanças economicas devido a entrada na OCDE, entretanto, nos anos seguintes, foi possível perceber uma queda significativa nestes índices. E, para completar a conclusão, foi realizado algumas pesquisas que afirmam que, para Israel, o ano de 2019, foi o ano com o menor indice de desemprego já registrado.
#
# Agora, argumentando com a adesão do país comparativo no gráfico, os dados dos países membros da OCDE possuem algumas irregularidades, o que permite que o país não-membro, em alguns anos possuia taxas menores, porém os membros fecham com uma média menor no período pós entrada no bloco do que o não-membro.
#
# Outro fator a ser analisado é o PIB/trabalhador, o qual, como apresentado no gráfico conclusivo, desde a entrada na Organização só houveram crescimentos nas taxas, o que implica que se o PIB aumentou a economia está num melhor estagio o que permite melhores oportunidades de emprego. Já no gráfico comparativo, é percebível que o não-membro descrepou-se significativamento dos outros países, possuindo um PIB/trabalhador inferior.
#
# Assim, ao juntar as duas informações é possível argumentar que a entrada na OCDE pode influênciar nos índices de desemprego e também economicos, o que gera resultados positivos em ambas as áreas, mesmo que eles sejam sutis, sendo possível dizer que a hipótese é verdadeira.
#
#
# ### Gráficos conclusivos:
# #### Para melhor entendimento, os países membros da OCDE estão em azul e o não-membro está de vermelho

# %%
dados_testeGPD = dados_paisesGDP.transpose()
plt.plot(dados_paisesGDP.loc["Israel"], color = "blue")
plt.plot(dados_paisesGDP.loc["Chile"], color = "darkblue")
plt.plot(dados_paisesGDP.loc["Estonia"], color = "aqua")
plt.plot(dados_paisesGDP.loc["Colombia"], color = "red")
plt.xlabel('Anos')
plt.ylabel("PIB/trabalhador")
plt.title('Gráfico comparativo no PIB')
plt.legend()
plt.grid()

# %%
pais_comparadoD = dados_paisesD.transpose()
plt.plot(dados_paisesD.loc["Israel"], color = "blue")
plt.plot(dados_paisesD.loc["Chile"], color = "darkblue")
plt.plot(dados_paisesD.loc["Estônia"], color = "aqua")
plt.plot(dados_paisesD.loc["Colômbia"], color = "red")
plt.xlabel('Anos')
plt.ylabel("Porcentagem de desempregados")
plt.title('Gráfico comparativo no desemprego')
plt.legend()
plt.grid()
